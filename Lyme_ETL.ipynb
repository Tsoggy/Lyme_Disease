# %%
import pandas as pd
import numpy as np
import os

# %%
file_path = "Data/"

# %%
df = pd.read_csv(f'{file_path}LymeCaseCountsbyCounty.csv', encoding='latin-1')
df.head(10)
# Out:
#            Ctyname   Stname  STCODE  CTYCODE  Cases2000  Cases2001  Cases2002  \
# 0   Autauga County  Alabama       1        1          0          0          0
# 1   Baldwin County  Alabama       1        3          1          0          1
# 2   Barbour County  Alabama       1        5          0          0          0
# 3      Bibb County  Alabama       1        7          0          0          0
# 4    Blount County  Alabama       1        9          0          0          0
# 5   Bullock County  Alabama       1       11          0          0          0
# 6    Butler County  Alabama       1       13          0          0          0
# 7   Calhoun County  Alabama       1       15          0          0          0
# 8  Chambers County  Alabama       1       17          0          0          0
# 9  Cherokee County  Alabama       1       19          0          0          0
#
#    Cases2003  Cases2004  Cases2005  ...  Cases2010  Cases2011  Cases2012  \
# ...

# %%
len(df)
# Out:
# 3193

# %%
df.columns
# Out:
# Index(['Ctyname', 'Stname', 'STCODE', 'CTYCODE', 'Cases2000', 'Cases2001',
#        'Cases2002', 'Cases2003', 'Cases2004', 'Cases2005', 'Cases2006',
#        'Cases2007', 'Cases2008', 'Cases2009', 'Cases2010', 'Cases2011',
#        'Cases2012', 'Cases2013', 'Cases2014', 'Cases2015', 'Cases2016',
#        'Cases2017', 'Cases2018', 'Cases2019'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Ctyname      object
# Stname       object
# STCODE        int64
# CTYCODE       int64
# Cases2000     int64
# Cases2001     int64
# Cases2002     int64
# Cases2003     int64
# Cases2004     int64
# Cases2005     int64
# Cases2006     int64
# Cases2007     int64
# Cases2008     int64
# Cases2009     int64
# Cases2010     int64
# Cases2011     int64
# Cases2012     int64
# Cases2013     int64
# Cases2014     int64
# Cases2015     int64
# Cases2016     int64
# Cases2017     int64
# Cases2018     int64
# Cases2019     int64
# dtype: object

# %%
df_2019 = df.drop(columns=['STCODE', 'Cases2000', 'Cases2001',
       'Cases2002', 'Cases2003', 'Cases2004', 'Cases2005', 'Cases2006',
       'Cases2007', 'Cases2008', 'Cases2009', 'Cases2010', 'Cases2011',
       'Cases2012', 'Cases2013', 'Cases2014', 'Cases2015', 'Cases2016','Cases2017','Cases2018'])

# %%
df_2019 = df_2019.rename(columns={'Ctyname':'County','Stname':'State'})
df_2019.head()
# Out:
#            County    State  CTYCODE  Cases2019
# 0  Autauga County  Alabama        1          1
# 1  Baldwin County  Alabama        3          0
# 2  Barbour County  Alabama        5          1
# 3     Bibb County  Alabama        7          0
# 4   Blount County  Alabama        9          0

# %%
df_2019.loc[df_2019['CTYCODE'] == 999]
# Out:
#               County           State  CTYCODE  Cases2019
# 67           Alabama         Alabama      999          0
# 97            Alaska          Alaska      999          0
# 113          Arizona         Arizona      999          0
# 189         Arkansas        Arkansas      999          0
# 248       California      California      999          0
# 313         Colorado        Colorado      999          0
# 322      Connecticut     Connecticut      999          7
# 326         Delaware        Delaware      999         25
# 395          Florida         Florida      999          0
# 555          Georgia         Georgia      999          0
# 561           Hawaii          Hawaii      999          0
# 606            Idaho           Idaho      999          0
# 709         Illinois        Illinois      999          0
# 802          Indiana         Indiana      999         62
# 902             Iowa            Iowa      999          0
# ...

# %%
df_2019.loc[df_2019['State']=='California']
# Out:
#                      County       State  CTYCODE  Cases2019
# 190          Alameda County  California        1         17
# 191           Alpine County  California        3          0
# 192           Amador County  California        5          0
# 193            Butte County  California        7          1
# 194        Calaveras County  California        9          1
# 195           Colusa County  California       11          0
# 196     Contra Costa County  California       13          4
# 197        Del Norte County  California       15          0
# 198        El Dorado County  California       17          0
# 199           Fresno County  California       19          1
# 200            Glenn County  California       21          0
# 201         Humboldt County  California       23          3
# 202         Imperial County  California       25          0
# 203             Inyo County  California       27          0
# 204             Kern County  California       29          0
# ...

# %%
df_2019.loc[df_2019['State']=='Virginia']
# Out:
#                    County     State  CTYCODE  Cases2019
# 2865      Accomack County  Virginia        1          1
# 2866     Albemarle County  Virginia        3         20
# 2867     Alleghany County  Virginia        5          0
# 2868        Amelia County  Virginia        7          0
# 2869       Amherst County  Virginia        9          7
# ...                   ...       ...      ...        ...
# 2995  Virginia Beach city  Virginia      810         13
# 2996      Waynesboro city  Virginia      820          1
# 2997    Williamsburg city  Virginia      830          2
# 2998      Winchester city  Virginia      840         12
# 2999             Virginia  Virginia      999        124
#
# [135 rows x 4 columns]

# %%
df_2019.value_counts()
# Out:
# County               State           CTYCODE  Cases2019
# Abbeville County     South Carolina  1        0            1
# Norfolk city         Virginia        710      1            1
# North Carolina       North Carolina  999      0            1
# North Dakota         North Dakota    999      0            1
# North Slope Borough  Alaska          185      0            1
#                                                           ..
# Goliad County        Texas           175      0            1
# Gonzales County      Texas           177      0            1
# Goochland County     Virginia        75       0            1
# Goodhue County       Minnesota       49       23           1
# Ziebach County       South Dakota    137      0            1
# Length: 3193, dtype: int64

# %%
df_2019.isnull().values.any()
# Out:
# False

# %%
df_2019.groupby(['State']).count()
# Out:
#                       County  CTYCODE  Cases2019
# State
# Alabama                   68       68         68
# Alaska                    30       30         30
# Arizona                   16       16         16
# Arkansas                  76       76         76
# California                59       59         59
# Colorado                  65       65         65
# Connecticut                9        9          9
# Delaware                   4        4          4
# District of Columbia       1        1          1
# Florida                   68       68         68
# Georgia                  160      160        160
# Hawaii                     6        6          6
# Idaho                     45       45         45
# Illinois                 103      103        103
# Indiana                   93       93         93
# Iowa                     100      100        100
# Kansas                   106      106        106
# Kentucky                 121      121        121
# ...
